# %%
import sys, subprocess
import json

# %%
file_input = "../../tv_series_data.json"
file_output = "series_plot_emotions.json"

command = [sys.executable, "series_classification.py", file_input, file_output]
result = subprocess.run(command, capture_output=True, text=True)

if result.stderr:
    print("Errors:")
    print(result.stderr)
    
print(result.stdout)
# Out:
# Errors:
# Device set to use cpu

# %%
import pandas as pd

pd.read_json("../../tv_series_data.json").tail()
# Out:
#                                  Title       Year Rated     Released  Runtime  \
# 4898                      Çilek Kokusu       2015   N/A  24 Jun 2015   90 min
# 4899  Çilgin Dersane at the University       2014   N/A  09 Jun 2014   90 min
# 4900                 Çocuklar Duymasin  2002–2019   N/A  16 Jan 2002      N/A
# 4901       Çok Güzel Hareketler Bunlar  2008–2011   N/A  07 May 2008  105 min
# 4902                       Ölene Kadar       2017   N/A  12 Jan 2017  120 min
#
#                Genre Director Writer  \
# 4898         Romance      N/A    N/A
# 4899          Comedy      N/A    N/A
# 4900  Comedy, Family      N/A    N/A
# 4901          Comedy      N/A    N/A
# 4902           Drama      N/A    N/A
#
#                                                  Actors  \
# 4898         Demet Özdemir, Yusuf Çim, Ekin Mert Daymaz
# 4899     Pashan Yilmazel, Duygu Çetinkaya, Okan Karacan
# 4900       Tamer Karadagli, Ferdi Akarnur, Zeyno Günenç
# ...

# %%
df1=pd.read_json("../../EmotionalDamageSeries.json")
df2=pd.read_json("../../EmotionalDamageSeries1.json")

with open("../../EmotionalUnrecoverySeries.json", "w") as f:
    pd.concat([df1, df2], ignore_index=True).to_json(f, orient="records")
