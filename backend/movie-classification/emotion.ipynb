# %%
# Libraries
import pandas as pd
import json
import sys, subprocess

# %%
# # Read the JSON file
file = "../movies_data.json"
with open(file, 'r') as f:
    data = json.load(f)

len(data)
# Out:
# 1532

# %%
# Run API Script

api_key = "AIzaSyCLhXuToPdOWRqquDe3uJY-_sy3IdOTxC0"

command = [sys.executable, "return_emotional_ratings.py", api_key, file]
result = subprocess.run(command, capture_output=True, text=True)

# Display the output
print("Output:")
print(result.stdout)

# If there were errors, you can print them as well
if result.stderr:
    print("Errors:")
    print(result.stderr)

output = json.loads(result.stdout)
# Out:
# Output:
# AIzaSyCLhXuToPdOWRqquDe3uJY-_sy3IdOTxC0
# {
#     "Title": "10 Cloverfield Lane",
#     "EmotionalRatings": {
#         "Sad_to_Happy": -0.4,
#         "Fear_to_Anger": 0.7,
#         "Anxious_to_Calm": -0.8
#     },
#     "Reasoning": "The movie creates a sustained atmosphere of suspense and paranoia.  The protagonist's confinement and uncertainty about the threat (both external and from the other characters) lead to a predominantly negative 'Sad_to_Happy' score.  The escalating tension and potential danger significantly increase the 'Fear_to_Anger' rating, as the viewer experiences the character's fear and potential for conflict. The overwhelming feeling of helplessness and uncertainty in a claustrophobic setting results in a very low 'Anxious_to_Calm' score, as the film rarely provides moments of relief or calm."
# }
# {
#     "Title": "10 Things I Hate About You",
#     "EmotionalRatings": {
#         "Sad_to_Happy": 0.7,
#         "Fear_to_Anger": -0.2,
# ...

# %%
# Out:
#                            Title  \
# 0            10 Cloverfield Lane
# 1     10 Things I Hate About You
# 2                   12 Angry Men
# 3                     12 Monkeys
# 4               12 Years a Slave
# ...                          ...
# 1527                  Zombieland
# 1528      Zombieland: Double Tap
# 1529                   Zoolander
# 1530                    Zootopia
# 1531                         xXx
#
#                                                    Plot
# 0     After getting in a car accident, Michelle awak...
# 1     Adapted from William Shakespeare's play "The T...
# 2     The defense and the prosecution have rested, a...
# 3     James Cole, a prisoner of the state in the yea...
# 4     Based on an incredible true story of one man's...
# ...                                                 ...
# 1527  Searching for family. In the early twenty-firs...
# 1528  One long decade after the post-apocalyptic eve...
# ...
