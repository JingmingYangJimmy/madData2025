# %%
import json

# Read the JSONL file
with open('/Users/bila/madison/2_Semester/hackathon/madData2025/movies_emotion_scores.jsonl', 'r') as file:
    data = [json.loads(line) for line in file]

# Extract NormalizedEmotion Sad-Happy with key existence check
sad_happy_values = [entry['NormalizedEmotion']['Sad-Happy'] for entry in data if 'NormalizedEmotion' in entry]
print(sad_happy_values)
len(sad_happy_values)
# Out:
# [0.3480732475450206, 0.1777362144929375, 0.4292972980541732, 0.2711528888226244, 0.9734364412564903, 0.027203314554888013, 0.8359679650536812, -0.19130479943424678, 0.11970464325218662, 0.6121088253427615, -0.030254040832526485, -0.029093555357623698, -0.6555008167968956, 0.10940006023463826, 0.8920885883150141, -0.23770691720351397, 0.5183060533766084, 0.998118447690493, -0.21237421875783566, 0.03921229787394048, -0.11653938889086696, -0.164246450999016, 0.49703250052297604, 0.8943256779855178, 0.42673079772636646, -0.48738418949819984, -0.5635316658249281, 0.7246594231437202, 0.8500710890126759, 0.6664313534559703, -0.1691813180833503, 0.7854592561025023, -0.017961558247134118, -0.42275762699032327, 0.3970059056047736, 0.8672747890126384, 0.8111812751060972, 0.4629024101000426, -0.27595244713228995, 0.9803359957101417, 0.900731291172426, 0.3694765667006867, -0.5090614007904183, 0.1940868190244457, -0.5306751947963599, -0.06252427863744212, -0.0740860993814579, 0.40999549791854795, 
# ...
